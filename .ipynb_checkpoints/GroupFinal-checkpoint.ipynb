# %%
import pandas as pd
import geopandas as gp
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Group #18 Final
#
# The goal of this project is to find the best neighborhood in Pittsburgh based on a metric of our choosing.
# The metric we chose for this project was the neighborhood with the best chance of having multi-sport athletes live there.
# We chose datasets including rinks, courts, fields, and pools in order to get the list of places to exercise in the neighborhoods surrounding Pittsburgh. After we got the top three, we gave them a score out of 15 points and the one with the most points won.

# %% [markdown]
# # Fields

# %%
field_data = pd.read_csv("field_data.csv")
area_Data = pd.read_csv("CensusTract.csv")

# %%
#Fields per neighborhood list in order
fields_per_hood = field_data['neighborhood'].value_counts()
fields_per_hood
# Out:
# Brighton Heights            7
# South Side Slopes           6
# Brookline                   6
# Squirrel Hill South         5
# Carrick                     5
# Lower Lawrenceville         4
# Mount Washington            4
# Hazelwood                   4
# Highland Park               4
# Sheraden                    3
# Shadyside                   3
# Troy Hill                   3
# Morningside                 3
# Beechview                   3
# Beltzhoover                 3
# Central Lawrenceville       2
# Bedford Dwellings           2
# Allegheny Center            2
# Greenfield                  2
# Manchester                  2
# Perry North                 2
# Spring Hill-City View       2
# Westwood                    2
# South Side Flats            2
# Elliott                     2
# South Oakland               2
# Regent Square               2
# Banksville                  2
# Crafton Heights             2
# Lincoln-Lemington-Belmar    2
# Windgap                     1
# Squirrel Hill North         1
# Polish Hill                 1
# West End                    1
# Allentown                   1
# Marshall-Shadeland          1
# Stanton Heights             1
# Oakwood                     1
# Spring Garden               1
# Perry South                 1
# Garfield                    1
# Lincoln Place               1
# Central Oakland             1
# Arlington                   1
# East Hills                  1
# East Liberty                1
# Larimer                     1
# Terrace Village             1
# Upper Lawrenceville         1
# Fineview                    1
# Homewood South              1
# Name: neighborhood, dtype: int64

# %%
#A histogram and density graph of fields per neighborhood
fields_per_hood.hist(bins=7)
fields_per_hood.plot.density()

# %%
# Boxplot for distribution and outliers
fields_per_hood.plot.box()

# %% [markdown]
# ### Baseball/Softball Diamonds

# %%
#Scatter plot of field sizes
threed = plt.figure().gca(projection='3d')
threed.scatter(field_data['center_field_distance'], field_data['left_field_distance'], field_data['right_field_distance'])
threed.set_xlabel('Center Field Distance')
threed.set_ylabel('Left Field DIstance')
threed.set_zlabel('Right Field Distance')
# Out:
# Text(0.5, 0, 'Right Field Distance')

# %% [markdown]
# Most fields are not full size and are for younger players. But the largest cluster is for boys under the age of 14, because by 14 you reach full or 60/90th (which is also the normal softball field size) size fields. The variation in the larger sizes is standard even in professional fields and are all equally playable.

# %% [markdown]
# ### Rectangular Fields
# With the only auxillary data on rectanugular fields being goal posts and lights, they will com into consideration later.

# %% [markdown]
# ### Raw Field Amount
# Some fields are soley diamond, rectangular, or a hybrid of the two. Below I analize the field baised

# %%
# adding a field count column
field_data['field_count'] = 1
# filter field data into a new variable
num_fields = field_data.groupby("neighborhood").sum()['field_count']

# %%
#read in the shapefile
neighborhoods = gp.read_file("Neighborhoods/Neighborhoods_.shp")
# merge data to shape map
fields_map = neighborhoods.merge(num_fields,how='left', left_on='hood', right_on='neighborhood')

# %%
# Color map baised on number of fields
fields_map.plot(column='field_count',
                cmap='YlGn',
                edgecolor="white",
                legend=True,
                legend_kwds={'label': "Number of Fields"},
                figsize=(10,5),
                missing_kwds={"color": "lightgrey"}
               )

# %% [markdown]
# ### Focusing In
# So far I have looked at the data based off of the number of fields in a colormap (diamond, rectangular, and hybrid). As well as the sizes of diamonds.Here I will take the top choices baised on amount into the next stage.

# %% [markdown]
# The remaining canidates being, Brighton Heights, South Side Slopes, Brookline, Squirrel Hill South, Carrick, Lower Lawrenceville, Mount Washington, Hazelwood, and Highland Park. From these nine I will decide on a top three.

# %% [markdown]
# ### Coming to a Conclusion: Jaden

# %% [markdown]
# Selection factors include, number of fields, diversity in field type, and field quality (goal poasts and lights). Each neighborhood get 1/2 of a point for a field, 2 extra points for field diversity, and 1/4 of a point for goal posts (football) and lights. By narrowing things down I wasable to more carfully construct my socing system and conclusions with carful analysis.

# %% [markdown]
# ## 1st Brookline

# %% [markdown]
# 2 hybrid fields \
# 1 rectangular field \
# 3 diamond fields \
# 4 goal posts \
# 4 lighted fields \
# Total Score of: 7

# %% [markdown]
# ## 2nd South Side Slopes

# %% [markdown]
# 5 diamond fields \
# 1 rectangular field \
# 4 lighted fields \
# 1 goal post \
# Total score of: 6.25

# %% [markdown]
# ## 3rd Carrick

# %% [markdown]
# 4 diomond fields \
# 1 rectangular field\
# 2 goal posts \
# 3 lighted fields \
# Total score of: 5.75

# %% [markdown]
# # Pools

# %%
##gets the data into a dataset
##also puts the data into a dataset of only pools, no splash parks
poolData = pd.read_csv('PghPools.csv')
poolData.sort_values(by='capacity', inplace = True, ascending = False)
query_mask = poolData['type'] == "Pool"
only_pools = poolData[query_mask]
only_pools
# Out:
#             id                 name  type  retired  \
# 8      5446687      Highland - Main  Pool      NaN
# 0    899591542                Ammon  Pool      NaN
# 14  2077053611                Moore  Pool      NaN
# 18    43656340                 Ream  Pool      NaN
# 3   1533382756           Bloomfield  Pool      NaN
# 21   976230017             Sheraden  Pool      NaN
# 22   927599833           Sue Murray  Pool      NaN
# 17  1704750315      Phillips - Main  Pool      NaN
# 24   558965267            West Penn  Pool      NaN
# 10  2092220498           Jack Stack  Pool      NaN
# 16   328662701               Ormsby  Pool      NaN
# 19  1747129029            Riverview  Pool      NaN
# 11   778775283                Magee  Pool      NaN
# 20  1396040949             Schenley  Pool      NaN
# 9    878134116             Homewood  Pool      NaN
# 1   1003800828           Banksville  Pool      NaN
# 25  1702052317             Westwood  Pool      NaN
# 15  1029407685               Oliver  Pool      NaN
# 12    23531050              McBride  Pool      NaN
# 7   1475037865  Highland - Children  Pool      NaN
#
#                             water_source  capacity  \
# 8   Pittsburgh Water and Sewer Authority  560242.0
# 0   Pittsburgh Water and Sewer Authority  538000.0
# 14           Pennsylvania American Water  417657.0
# 18  Pittsburgh Water and Sewer Authority  356000.0
# 3   Pittsburgh Water and Sewer Authority  335000.0
# 21           Pennsylvania American Water  278000.0
# 22  Pittsburgh Water and Sewer Authority  271000.0
# 17  Pittsburgh Water and Sewer Authority  224100.0
# 24  Pittsburgh Water and Sewer Authority  215451.0
# 10  Pittsburgh Water and Sewer Authority  205800.0
# 16  Pittsburgh Water and Sewer Authority  205800.0
# 19  Pittsburgh Water and Sewer Authority  205800.0
# 11  Pittsburgh Water and Sewer Authority  195000.0
# 20  Pittsburgh Water and Sewer Authority  187600.0
# 9   Pittsburgh Water and Sewer Authority  171075.0
# 1            Pennsylvania American Water  166320.0
# 25           Pennsylvania American Water  156840.0
# 15           Pennsylvania American Water  107000.0
# 12           Pennsylvania American Water   18000.0
# 7   Pittsburgh Water and Sewer Authority       NaN
#
#                                                 image         neighborhood  \
# 8   https://tools.wprdc.org/images/pittsburgh/pool...        Highland Park
# 0   https://tools.wprdc.org/images/pittsburgh/pool...    Bedford Dwellings
# 14  https://tools.wprdc.org/images/pittsburgh/pool...            Brookline
# 18  https://tools.wprdc.org/images/pittsburgh/pool...     Mount Washington
# 3   https://tools.wprdc.org/images/pittsburgh/pool...           Bloomfield
# 21  https://tools.wprdc.org/images/pittsburgh/pool...             Sheraden
# 22  https://tools.wprdc.org/images/pittsburgh/pool...     Allegheny Center
# 17  https://tools.wprdc.org/images/pittsburgh/pool...              Carrick
# 24  https://tools.wprdc.org/images/pittsburgh/pool...          Polish Hill
# 10  https://tools.wprdc.org/images/pittsburgh/pool...     Brighton Heights
# 16  https://tools.wprdc.org/images/pittsburgh/pool...     South Side Flats
# 19  https://tools.wprdc.org/images/pittsburgh/pool...          Perry North
# 11  https://tools.wprdc.org/images/pittsburgh/pool...           Greenfield
# 20  https://tools.wprdc.org/images/pittsburgh/pool...  Squirrel Hill South
# 9   https://tools.wprdc.org/images/pittsburgh/pool...       Homewood South
# 1   https://tools.wprdc.org/images/pittsburgh/pool...           Banksville
# 25  https://tools.wprdc.org/images/pittsburgh/pool...             Westwood
# 15  https://tools.wprdc.org/images/pittsburgh/pool...     South Side Flats
# 12  https://tools.wprdc.org/images/pittsburgh/pool...        Lincoln Place
# 7   https://tools.wprdc.org/images/pittsburgh/pool...        Highland Park
#
#     council_district  ward        tract  public_works_division  pli_division  \
# 8                  7    11  42003980100                      2            11
# 0                  6     5  42003050900                      3             5
# 14                 4    19  42003191700                      5            19
# 18                 2    19  42003190300                      5            19
# 3                  7     8  42003080200                      2             8
# 21                 2    20  42003562500                      5            20
# 22                 1    22  42003562700                      1            22
# 17                 4    29  42003290400                      3            29
# 24                 7     6  42003060500                      6             6
# 10                 1    27  42003270800                      1            27
# 16                 3    16  42003160900                      3            16
# 19                 1    26  42003980400                      1            26
# 11                 5    15  42003151700                      3            15
# 20                 5    14  42003980500                      3            14
# 9                  9    13  42003130300                      2            13
# 1                  2    20  42003202300                      5            20
# 25                 2    28  42003563100                      5            28
# 15                 3    17  42003170200                      3            17
# 12                 5    31  42003310200                      3            31
# 7                  7    11  42003980100                      2            11
#
#     police_zone fire_zone   latitude  longitude
# 8             5       3-9  40.482170 -79.910927
# 0             2       2-5  40.448720 -79.978325
# 14            6      4-26  40.405583 -80.013514
# 18            3      4-27  40.430828 -80.013111
# 3             5       3-1  40.461989 -79.953310
# 21            6      1-16  40.457096 -80.059847
# 22            1       1-6  40.451282 -80.001504
# 17            3      4-23  40.392045 -79.991103
# 24            2       2-6  40.455276 -79.969926
# 10            1      1-14  40.486884 -80.030632
# 16            3      4-24  40.428950 -79.974114
# 19            1      1-15  40.479689 -80.018441
# 11            4      2-15  40.424814 -79.937006
# 20            4       2-8  40.434715 -79.947010
# 9             5      3-17  40.454310 -79.899891
# 1             6       4-9  40.414758 -80.040551
# 25            6      1-18  40.430807 -80.049759
# 15            3       4-2  40.429628 -79.988922
# 12            4      4-20  40.370392 -79.907340
# 7             5       3-9  40.482011 -79.911280

# %%
only_pools['neighborhood']
# Out:
# 8           Highland Park
# 0       Bedford Dwellings
# 14              Brookline
# 18       Mount Washington
# 3              Bloomfield
# 21               Sheraden
# 22       Allegheny Center
# 17                Carrick
# 24            Polish Hill
# 10       Brighton Heights
# 16       South Side Flats
# 19            Perry North
# 11             Greenfield
# 20    Squirrel Hill South
# 9          Homewood South
# 1              Banksville
# 25               Westwood
# 15       South Side Flats
# 12          Lincoln Place
# 7           Highland Park
# Name: neighborhood, dtype: object

# %%
plt.bar(only_pools['neighborhood'], only_pools['capacity'], color = 'blue', width = 0.5)
plt.xlabel("Neighborhoods with pools")
plt.ylabel("Pool water capacity")
plt.title("Pools and Their Capacities")
plt.xticks(rotation=90)
plt.show()

# %%
cap_pools = only_pools.groupby("neighborhood").sum()['capacity']
neighborhood = gp.read_file("Neighborhoods/Neighborhoods_.shp")
pool_map = neighborhood.merge(cap_pools, how = 'left', left_on='hood', right_on='neighborhood')

# %%
pool_map.plot(column='capacity',
                cmap='PuBu',
                edgecolor="white",
                legend=True,
                legend_kwds={'label': "Capacity of The Pool per Neighborhood"},
                figsize=(10,8),
                missing_kwds={"color": "lightgrey"}
               )

# %%
only_pools.head(5)
# Out:
#             id             name  type  retired  \
# 8      5446687  Highland - Main  Pool      NaN
# 0    899591542            Ammon  Pool      NaN
# 14  2077053611            Moore  Pool      NaN
# 18    43656340             Ream  Pool      NaN
# 3   1533382756       Bloomfield  Pool      NaN
#
#                             water_source  capacity  \
# 8   Pittsburgh Water and Sewer Authority  560242.0
# 0   Pittsburgh Water and Sewer Authority  538000.0
# 14           Pennsylvania American Water  417657.0
# 18  Pittsburgh Water and Sewer Authority  356000.0
# 3   Pittsburgh Water and Sewer Authority  335000.0
#
#                                                 image       neighborhood  \
# 8   https://tools.wprdc.org/images/pittsburgh/pool...      Highland Park
# 0   https://tools.wprdc.org/images/pittsburgh/pool...  Bedford Dwellings
# 14  https://tools.wprdc.org/images/pittsburgh/pool...          Brookline
# 18  https://tools.wprdc.org/images/pittsburgh/pool...   Mount Washington
# 3   https://tools.wprdc.org/images/pittsburgh/pool...         Bloomfield
#
#     council_district  ward        tract  public_works_division  pli_division  \
# 8                  7    11  42003980100                      2            11
# 0                  6     5  42003050900                      3             5
# 14                 4    19  42003191700                      5            19
# 18                 2    19  42003190300                      5            19
# 3                  7     8  42003080200                      2             8
#
#     police_zone fire_zone   latitude  longitude
# 8             5       3-9  40.482170 -79.910927
# 0             2       2-5  40.448720 -79.978325
# 14            6      4-26  40.405583 -80.013514
# 18            3      4-27  40.430828 -80.013111
# 3             5       3-1  40.461989 -79.953310

# %% [markdown]
# # Dom's Conclusion: Pools
# The metric I used was the water capacity of pools in the Pittsburgh area. I chose the capacity because there is usually one pool per neighborhood and in order to compare how large the pools are, I needed to use the capacity. A higher capacity means more people at a time are in the pool and on their way to becoming multi-sport athletes. The pools with the top 5 capacities are Highland - Main Pool, Ammon Pool, Moore Pool, Ream Pool, and Bloomfield Pool respectively.
#
# ## Point Total
# ### -----------
# 1.) Highland - Main Pool in Highland Park 5 / 5
#
# 2.) Ammon Pool in Bedford Dwellings 4.8 / 5
#
# 3.) Moore Pool in Brookline 4.2 / 5

# %% [markdown]
# # Rinks and Courts

# %% [markdown]
# ## Import the data

# %%
#import the data
import pandas as pd
import geopandas as gp
# %matplotlib inline
data = pd.read_csv("courts-and-rinks.csv")
pd.set_option('display.max_rows', 10)

# %%
#make a graph showing the top 10 places with the most courts
graph = data['neighborhood'].value_counts()[:10]
graph.plot.barh()

#give a contextualizing statement
print('The top three places with the most courts are Squirrel Hill, South Highland Park, and Hazelwood!')

#print out the counts of the places wotht he most courts
data['neighborhood'].value_counts()
# Out:
# The top three places with the most courts are Squirrel Hill, South Highland Park, and Hazelwood!
# Squirrel Hill South      26
# Highland Park            20
# Hazelwood                10
# Beltzhoover               9
# Brookline                 9
#                          ..
# Marshall-Shadeland        1
# Central Lawrenceville     1
# Hays                      1
# Bon Air                   1
# Larimer                   1
# Name: neighborhood, Length: 63, dtype: int64

# %% [markdown]
# ## Make the graph

# %%
data['field_count'] = 1
type_fields = data.groupby("neighborhood").sum()['field_count']
neighborhoods = gp.read_file("Neighborhoods/Neighborhoods_.shp")

# %% [markdown]
# ## Graphing the data

# %%
fields_map = neighborhoods.merge(type_fields,how='left', left_on='hood', right_on='neighborhood')
fields_map.plot(column='field_count',
                cmap='YlGn',
                edgecolor="white",
                legend=True,
                legend_kwds={'label': "Number of Fields"},
                figsize=(10,5),
                missing_kwds={"color": "lightgrey"}
               )

# %% [markdown]
# ## Joe's Conclusion
# At the end of all of this analysis the data shows that Squirrel Hill South is at the top with 26 courts and fields, then Highland Park with 20 courts and fields, Hazelwood with 10 courts and fields, and Beltzhoover and Brookline tied with 9 courts and fields.

# %% [markdown]
# # Final Conclusion
#
#     We found that throughout these datasets there is one neighborhood that has the best and most athletic facilities be it rinks, fields, courts and pools. That neighborhood is
# ### Highland Park
#     As we went through the list we found that the data did not line up as well as we wanted to and so we had to search throughout all of our data to find some that correlated between the lists.
#
# ## Point Totals
# ## ------------
#
# 1.) Highland Park 13 / 15
#
# 2.) Brookline 12.5 / 15
#
# 3.) South Side Slopes 10 / 15
